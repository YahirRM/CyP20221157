# %% [markdown]
# <a href="https://colab.research.google.com/github/YahirRM/CyP20221157/blob/main/Tarea7_CyP_1157.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 03/02/2021

# %%
# PROBLEMA 3.1

SUMPAR=0
SUMIMP=0
CUEPAR=0

for i in range (0,270):
    NUM = int(input("Ingrese un valor entero: ")) 
    RES = NUM % 2
    if RES == 0:
      SUMPAR = SUMPAR + NUM 
      CUEPAR = CUEPAR + 1
    else: 
     SUMIMP = SUMIMP + NUM
 
PROPAR = SUMPAR/CUEPAR
print(f"El promedio es: {PROPAR}")
print(f"La suma de los impares es: {SUMIMP}")
# Out:
# Ingrese un valor entero: 1
# Ingrese un valor entero: 2
# Ingrese un valor entero: 3
# Ingrese un valor entero: 4
# Ingrese un valor entero: 5
# Ingrese un valor entero: 6
# Ingrese un valor entero: 7
# Ingrese un valor entero: 8
# Ingrese un valor entero: 9
# Ingrese un valor entero: 10
# Ingrese un valor entero: 11
# Ingrese un valor entero: 12
# Ingrese un valor entero: 13
# Ingrese un valor entero: 14
# Ingrese un valor entero: 15
# Ingrese un valor entero: 16
# Ingrese un valor entero: 17
# Ingrese un valor entero: 18
# Ingrese un valor entero: 19
# Ingrese un valor entero: 20
# Ingrese un valor entero: 21
# Ingrese un valor entero: 22
# Ingrese un valor entero: 23
# Ingrese un valor entero: 24
# Ingrese un valor entero: 25
# Ingrese un valor entero: 26
# Ingrese un valor entero: 27
# Ingrese un valor entero: 28
# Ingrese un valor entero: 29
# Ingrese un valor entero: 30
# Ingrese un valor entero: 31
# Ingrese un valor entero: 32
# Ingrese un valor entero: 33
# ...

# %%
# PROBLEMA 3.2
band='T'
i=2
sumser=0
while i<=1800:
    sumser=sumser+i
    print(i)
    if band=='T':
        band='F'
        i=i+3
    else:
        band='T'
        i=i+2
print(f"La suma es {sumser}")
# Out:
# 2
# 5
# 7
# 10
# 12
# 15
# 17
# 20
# 22
# 25
# 27
# 30
# 32
# 35
# 37
# 40
# 42
# 45
# 47
# 50
# 52
# 55
# 57
# 60
# 62
# 65
# 67
# 70
# 72
# 75
# 77
# 80
# 82
# 85
# 87
# 90
# 92
# 95
# 97
# 100
# 102
# 105
# 107
# 110
# 112
# 115
# 117
# 120
# 122
# 125
# 127
# 130
# 132
# 135
# 137
# 140
# 142
# 145
# 147
# 150
# 152
# 155
# 157
# 160
# 162
# 165
# 167
# 170
# 172
# 175
# 177
# 180
# 182
# 185
# 187
# 190
# 192
# 195
# 197
# 200
# 202
# 205
# 207
# 210
# 212
# 215
# 217
# 220
# 222
# 225
# 227
# 230
# 232
# 235
# 237
# 240
# 242
# 245
# 247
# 250
# 252
# 255
# 257
# 260
# 262
# 265
# 267
# 270
# 272
# 275
# 277
# 280
# 282
# 285
# 287
# 290
# 292
# 295
# 297
# 300
# 302
# 305
# 307
# 310
# 312
# 315
# 317
# 320
# 322
# 325
# 327
# 330
# 332
# 335
# 337
# 340
# 342
# 345
# 347
# 350
# 352
# 355
# 357
# 360
# 362
# 365
# 367
# 370
# 372
# 375
# 377
# 380
# 382
# 385
# 387
# 390
# 392
# 395
# 397
# 400
# 402
# 405
# 407
# 410
# 412
# 415
# 417
# 420
# 422
# 425
# 427
# 430
# 432
# ...

# %%
# PROBLEMA 3.3

N=int(input("Dame un numero entero: "))
band='T'
serie = 0
i=1
while i<=N:
    if band=='T':
        serie=serie+(1/i)
        band='F'
    else: 
        serie=serie-(1/i)
        band='T'
    i=i+1
print("El resultado de la serie es: ",round(serie,4))
# Out:
# Dame un numero entero: 9
# El resultado de la serie es:  0.7456

# %%
# PROBLEMA 3.4

NOM=0
SUE = float(input("Ingresa tu sueldo: "))
i=0
while SUE !=-1:
    if SUE < 1000:
        NSUE = SUE * 1.15
    else:
        NSUE = SUE * 1.12

    NOM = NOM + NSUE 
    i=i+1
    print("El nuevo sueldo del trabajador es: ",round(NSUE,2))
    SUE = float(input("Ingresa tu sueldo: "))

print(f"\nLa nomina es {nom}")
# Out:
# Ingresa tu sueldo: 855
# El nuevo sueldo del trabajador es:  983.25
# Ingresa tu sueldo: 760.32
# El nuevo sueldo del trabajador es:  874.37
# Ingresa tu sueldo: 1100.20
# El nuevo sueldo del trabajador es:  1232.22
# Ingresa tu sueldo: 614
# El nuevo sueldo del trabajador es:  706.1
# Ingresa tu sueldo: 2600
# El nuevo sueldo del trabajador es:  2912.0
# Ingresa tu sueldo: 817.50
# El nuevo sueldo del trabajador es:  940.12
# Ingresa tu sueldo: 1280.30
# El nuevo sueldo del trabajador es:  1433.94
# Ingresa tu sueldo: 687
# El nuevo sueldo del trabajador es:  790.05
# Ingresa tu sueldo: -1
#
# La nomina es 9872.05
